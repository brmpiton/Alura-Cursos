# %% [markdown]
# # NAula 1

# %%
with open("artigos.txt", "r") as f:
    artigos = f.read()

print(artigos[:500])
# Out:
# imagem
#
# Temos a seguinte classe que representa um usuário no nosso sistema:
#
# java
#
# Para salvar um novo usuário, várias validações são feitas, como por exemplo: Ver se o nome só contém letras, [**o CPF só números**] e ver se o usuário possui no mínimo 18 anos. Veja o método que faz essa validação:
#
# java
#
# Suponha agora que eu tenha outra classe, a classe `Produto`, que contém um atributo nome e eu quero fazer a mesma validação que fiz para o nome do usuário: Ver se só contém letras. E aí? Vou

# %%
len(artigos)# o len dá o número de letras, e não o de palavras
# Out:
# 2605046

# %%
len("Olá")
# Out:
# 3

# %%
texto_exemplo = "Olá, tudo bem?"
tokens = texto_exemplo.split()# split separa palavras

# %%
print(len(tokens))
# Out:
# 3

# %%
print(tokens)
# Out:
# ['Olá,', 'tudo', 'bem?']

# %% [markdown]
# # Aula 2

# %%
import nltk#vamos usar o nltk  para criar os tokens(palavras separadas) analise textual
nltk.download('punkt')#voce precisa instalar esse pacote pra poder usar o nltk- word_tokenize
palavras_separadas = nltk.tokenize.word_tokenize(texto_exemplo)#word_tokenize vai fazer o que queremos
print(palavras_separadas)#separou até as pontuações
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Olá', ',', 'tudo', 'bem', '?']

# %%
print(palavras_separadas)
# Out:
# ['Olá', ',', 'tudo', 'bem', '?']

# %%
len(palavras_separadas)
# Out:
# 5

# %%
'./'.isalpha()#testando se ./ é alfabético => não é
# Out:
# False

# %%
def separa_palavras(lista_tokens): #vamos criar essa função pra separar palavras dos pontos, para deixar só as palavras
    lista_palavras = []
    for token in lista_tokens:
        if token.isalpha():#vai pegar todos os simbolos não alfabéticos
            lista_palavras.append(token)
    return lista_palavras

separa_palavras(palavras_separadas)
# Out:
# ['Olá', 'tudo', 'bem']

# %%
lista_tokens = nltk.tokenize.word_tokenize(artigos)
lista_palavras = separa_palavras(lista_tokens)#aplica a funcao em tokens
print(f"Número de palavras é {len(lista_palavras)}")#conseguimos mostrar quantas palavras tem no nosso dataset
# Out:
# Número de palavras é 393914

# %%
print(lista_palavras[:10])
# Out:
# ['imagem', 'Temos', 'a', 'seguinte', 'classe', 'que', 'representa', 'um', 'usuário', 'no']

# %%
def normalizacao(lista_palavras):#vamos tentar descobrir quantos TIPOS de palavras temos. Palavras repetidas não contam
    lista_normalizada = []
    for palavra in lista_palavras:
        lista_normalizada.append(palavra.lower())
    return lista_normalizada

lista_normalizada = normalizacao(lista_palavras)#aplicando a função de normalização
print(lista_normalizada[:10])
# Out:
# ['imagem', 'temos', 'a', 'seguinte', 'classe', 'que', 'representa', 'um', 'usuário', 'no']

# %%
len(set(lista_normalizada))#Vemos a quantidade de TIPOS de palavras#Set vai REMOVER as repetições
# Out:
# 17652

# %% [markdown]
# # Aula 3

# %%
lista = "lgica"
(lista[:1],lista[1:])#revisando como funciona o index na lista. Vamos usar ali no gerador_palavras.
# Out:
# ('l', 'gica')

# %%
"como pegamos a palavra lgica e transformamos em lógica"
palavra_exemplo = "lgica"

def insere_letras(fatias):#essa função vai separar a palavra em duas partes para colocar alguma letra e ver se encontra alguma palavra formada dentro do nosso dataset
    novas_palavras = []
    letras = 'abcdefghijklmnopqrstuvwxyzáâàãéêèẽíîìĩóôõòúûùũç'
    for E, D in fatias:
        for letra in letras:
            novas_palavras.append(E + letra + D)
    return novas_palavras

def gerador_palavras(palavra):
    fatias = []
    for i in range(len(palavra)+1):#adicionamos +1 para não dar problema com o indice
        fatias.append((palavra[:i],palavra[i:]))#(lado esquerdo, lado direito)
    palavras_geradas = insere_letras(fatias)
    return palavras_geradas

palavras_geradas = gerador_palavras(palavra_exemplo)
print(palavras_geradas)#geramos um conjunto com todas as possibilidades. A palavra lógica está incluida
# Out:
# ['algica', 'blgica', 'clgica', 'dlgica', 'elgica', 'flgica', 'glgica', 'hlgica', 'ilgica', 'jlgica', 'klgica', 'llgica', 'mlgica', 'nlgica', 'olgica', 'plgica', 'qlgica', 'rlgica', 'slgica', 'tlgica', 'ulgica', 'vlgica', 'wlgica', 'xlgica', 'ylgica', 'zlgica', 'álgica', 'âlgica', 'àlgica', 'ãlgica', 'élgica', 'êlgica', 'èlgica', 'ẽlgica', 'ílgica', 'îlgica', 'ìlgica', 'ĩlgica', 'ólgica', 'ôlgica', 'õlgica', 'òlgica', 'úlgica', 'ûlgica', 'ùlgica', 'ũlgica', 'çlgica', 'lagica', 'lbgica', 'lcgica', 'ldgica', 'legica', 'lfgica', 'lggica', 'lhgica', 'ligica', 'ljgica', 'lkgica', 'llgica', 'lmgica', 'lngica', 'logica', 'lpgica', 'lqgica', 'lrgica', 'lsgica', 'ltgica', 'lugica', 'lvgica', 'lwgica', 'lxgica', 'lygica', 'lzgica', 'lágica', 'lâgica', 'làgica', 'lãgica', 'légica', 'lêgica', 'lègica', 'lẽgica', 'lígica', 'lîgica', 'lìgica', 'lĩgica', 'lógica', 'lôgica', 'lõgica', 'lògica', 'lúgica', 'lûgica', 'lùgica', 'lũgica', 'lçgica', 'lgaica', 'lgbica', 'lgcica', 'lgdica', 'lgeica', 'lgfica
# ...

# %%
def corretor(palavra):
    palavras_geradas = gerador_palavras(palavra)
    palavra_correta = max(palavras_geradas, key=probabilidade)#vamos constuir a função probabilidade ali em baixo
    return palavra_correta

# %%
frequencia = nltk.FreqDist(lista_normalizada) #usamos a função freq dist do nltk pra calcular a probabilidade
total_palavras = len(lista_normalizada)
frequencia.most_common(10)#mostra as palavras com maior freqência
# Out:
# [('de', 15494),
#  ('o', 13966),
#  ('que', 12225),
#  ('a', 11034),
#  ('e', 10478),
#  ('para', 7694),
#  ('um', 6346),
#  ('é', 5881),
#  ('uma', 5202),
#  ('do', 5116)]

# %%
def probabilidade(palavra_gerada):
    return frequencia[palavra_gerada]/total_palavras#freq/total palavras

probabilidade("logica")#podemos testar os tipos de lgica e ver suas prob
# Out:
# 0.0

# %%
probabilidade("lógica")#resolvemos somente um tipo de erro: de escrever uma letra errada. Precisamos corrigir vários outros
# Out:
# 0.00022086039084673304

# %% [markdown]
# # Aula 4

# %%
corretor(palavra_exemplo)
# Out:
# 'lógica'

# %%
def cria_dados_teste(nome_arquivo):
    lista_palavras_teste = []
    f = open(nome_arquivo, "r")#r seria "leitura"
    for linha in f:# vai pegar cada linha
        correta, errada = linha.split()
        lista_palavras_teste.append((correta, errada))
    f.close()
    return lista_palavras_teste

lista_teste = cria_dados_teste("palavras.txt")#carregamos o nosso outro banco de dados com as palavras corretas e erradas
lista_teste#agora vamos criar a função avaliador, que vai calcular a taxa de acerto do corretor

# %%
def avaliador(testes):
    numero_palavras = len(testes)
    acertou = 0
    for correta, errada in testes:
        palavra_corrigida = corretor(errada)
        if palavra_corrigida == correta:
            acertou += 1
    taxa_acerto = round(acertou*100/numero_palavras, 2)
    print(f"{taxa_acerto}% de {numero_palavras} palavras")

avaliador(lista_teste)#sai o resultado da probablidade de acerto. no caso é 1%, um número muito baixo

# %% [markdown]
# # Aula (aula 5)

# %%
def deletando_caracteres(fatias):#algoritmo para corrigir quando coloca uma letra amais (precisamos então deletar um caracter)
    novas_palavras = []
    for E, D in fatias:
        novas_palavras.append(E + D[1:])#faz com que vc não pegue uma letra do lado direto, "tirando-a"
    return novas_palavras

# %%
def gerador_palavras(palavra): #vamos adaptar o gerador de palavras(já tinhamos feito lá para cima)
    fatias = []
    for i in range(len(palavra)+1):
        fatias.append((palavra[:i],palavra[i:]))
    palavras_geradas = insere_letras(fatias)
    palavras_geradas += deletando_caracteres(fatias)
    return palavras_geradas
palavra_exemplo = "lóigica"#vamos testar com esse exemplo
palavras_geradas = gerador_palavras(palavra_exemplo)
print(palavras_geradas)
# Out:
# ['alóigica', 'blóigica', 'clóigica', 'dlóigica', 'elóigica', 'flóigica', 'glóigica', 'hlóigica', 'ilóigica', 'jlóigica', 'klóigica', 'llóigica', 'mlóigica', 'nlóigica', 'olóigica', 'plóigica', 'qlóigica', 'rlóigica', 'slóigica', 'tlóigica', 'ulóigica', 'vlóigica', 'wlóigica', 'xlóigica', 'ylóigica', 'zlóigica', 'álóigica', 'âlóigica', 'àlóigica', 'ãlóigica', 'élóigica', 'êlóigica', 'èlóigica', 'ẽlóigica', 'ílóigica', 'îlóigica', 'ìlóigica', 'ĩlóigica', 'ólóigica', 'ôlóigica', 'õlóigica', 'òlóigica', 'úlóigica', 'ûlóigica', 'ùlóigica', 'ũlóigica', 'çlóigica', 'laóigica', 'lbóigica', 'lcóigica', 'ldóigica', 'leóigica', 'lfóigica', 'lgóigica', 'lhóigica', 'lióigica', 'ljóigica', 'lkóigica', 'llóigica', 'lmóigica', 'lnóigica', 'loóigica', 'lpóigica', 'lqóigica', 'lróigica', 'lsóigica', 'ltóigica', 'luóigica', 'lvóigica', 'lwóigica', 'lxóigica', 'lyóigica', 'lzóigica', 'láóigica', 'lâóigica', 'làóigica', 'lãóigica', 'léóigica', 'lêóigica', 'lèóigica', 'lẽóigica', 'líóigica', 'lîóigica', '
# ...

# %%
avaliador(lista_teste)#aumentamos para 41% das palavras
# Out:
# 41.4% de 186 palavras

# %% [markdown]
# # Aula 6

# %%
#resolvemos erros de letra amais , letra faltante e letra errada. Agora vamos resolver quando erramos a ordem das letras (ex Brnuo)
def insere_letras(fatias):#essa nossa primeira funcao (esquecemos uma letra)
    novas_palavras = []
    letras = 'abcdefghijklmnopqrstuvwxyzáâàãéêèẽíîìĩóôõòúûùũç'
    for E, D in fatias:
        for letra in letras:
            novas_palavras.append(E + letra + D)
    return novas_palavras

def deletando_caracteres(fatias):#essa é nossa segunda funcao (escrevemos uma amais)
    novas_palavras = []
    for E, D in fatias:
        novas_palavras.append(E + D[1:])
    return novas_palavras

def troca_letra(fatias):#(trocando letra por outra)
    novas_palavras = []
    letras = 'abcdefghijklmnopqrstuvwxyzáâàãéêèẽíîìĩóôõòúûùũç'
    for E, D in fatias:
        for letra in letras:
            novas_palavras.append(E + letra + D[1:])
    return novas_palavras

def inverte_letra(fatias):#Burno(inverte a ordem) ESSA É A QUE VAMOS CRIAR AGORA#######
    novas_palavras = []
    for E, D in fatias:
        if len(D) > 1:
            novas_palavras.append(E + D[1] + D[0] + D[2:])#Esse d[1] e d[0] seria a letra que foi pra antes e a que foi pra dps
    return novas_palavras

def gerador_palavras(palavra): #ESssa função é a junção de todas as outras
    fatias = []
    for i in range(len(palavra)+1):
        fatias.append((palavra[:i],palavra[i:]))
    palavras_geradas = insere_letras(fatias)
    palavras_geradas += deletando_caracteres(fatias)#+= é pra fazer a concatenação dessas funções
    palavras_geradas += troca_letra(fatias)
    palavras_geradas += inverte_letra(fatias)
    return palavras_geradas

avaliador(lista_teste)
palavra_exemplo = "lógiac"
palavras_geradas = gerador_palavras(palavra_exemplo)
print(palavras_geradas)#AGORA ESTAMOS ACERTANDO 76% das palavras. Este erro está associado ao corretor, mas também a quantidade de 'palavras conhecidas'
# Out:
# 76.34% de 186 palavras
# ...

# %%
avaliador(lista_teste)
# Out:
# 76.34% de 186 palavras

# %% [markdown]
# # Aula 7

# %%
#Precisamos aumentar nosso "vocabulário". Precisamos descobrir o quanto do nosso erro é provocado pelo pouco vocabulario
def avaliador(testes, vocabulario):
    numero_palavras = len(testes)
    acertou = 0
    desconhecida = 0#Criamos esssa variavel para usar ali embaixo
    for correta, errada in testes:
        palavra_corrigida = corretor(errada)
        if palavra_corrigida == correta:
            acertou += 1
        else:#Vamos incrementar quando a palavra correta não estiver no vocabulario
            desconhecida += (correta not in vocabulario)    
    taxa_acerto = round(acertou*100/numero_palavras, 2)
    taxa_desconhecida = round(desconhecida*100/numero_palavras, 2)#é isso aqui que vamos mudar
    print(f"{taxa_acerto}% de {numero_palavras} palavras, desconhecida é {taxa_desconhecida}%")

vocabulario = set(lista_normalizada)
avaliador(lista_teste, vocabulario)#agora vemos a porcentagem das palavras desconhecidas
# Out:
# 76.34% de 186 palavras, desconhecida é 6.99%

# %%
palavra = "lóiigica"#erro 2x maior, precisaria usar a função duas vezes

def gerador_turbinado(palavras_geradas):#Essa funcao usa aoós o resultado da gerador_palavra
    novas_palavras = []
    for palavra in palavras_geradas:
        novas_palavras += gerador_palavras(palavra)
    return novas_palavras

palavras_g = gerador_turbinado(gerador_palavras(palavra))#ela corrige a correcao do gerador_palavra
"lógica" in palavras_g
# Out:
# True

# %%
len(palavras_g)
# Out:
# 787396

# %%
def novo_corretor(palavra):
    palavras_geradas = gerador_palavras(palavra)
    palavras_turbinado = gerador_turbinado(palavras_geradas)
    todas_palavras = set(palavras_geradas + palavras_turbinado)
    candidatos = [palavra]
    for palavra in todas_palavras:
        if palavra in vocabulario:
            candidatos.append(palavra)
    palavra_correta = max(candidatos, key=probabilidade)
    return palavra_correta

novo_corretor(palavra)#conseguimos corrigir
# Out:
# 'lógica'

# %% [markdown]
# # Aula 8

# %%
#precisamos comparar os nossos corretores(qual é melhor). Então vamos modificar a funcao avaliador
def avaliador(testes, vocabulario):
    numero_palavras = len(testes)
    acertou = 0
    desconhecida = 0
    for correta, errada in testes:
        palavra_corrigida = novo_corretor(errada)
        desconhecida += (correta not in vocabulario)
        if palavra_corrigida == correta:
            acertou += 1 
        else:#ESSE ELSE ESTá ERRADO, LOGO PRECISAMOS MODIFICAR
            print(errada + "-" + corretor(errada) + "-" + palavra_corrigida)
    taxa_acerto = round(acertou*100/numero_palavras, 2)
    taxa_desconhecida = round(desconhecida*100/numero_palavras, 2)
    print(f"{taxa_acerto}% de {numero_palavras} palavras, desconhecida é {taxa_desconhecida}%")

vocabulario = set(lista_normalizada)
avaliador(lista_teste, vocabulario)#PRECISAMOS MODIFICAR ESSE CÒDIGO. Ali embaixo está o jeito certo

# %%
def avaliador(testes, vocabulario):
    numero_palavras = len(testes)
    acertou = 0
    desconhecida = 0
    for correta, errada in testes:#Agora nosso else não vai dar problema
        palavra_corrigida = corretor(errada)
        desconhecida += (correta not in vocabulario)
        if palavra_corrigida == correta:
            acertou += 1 
    taxa_acerto = round(acertou*100/numero_palavras, 2)
    taxa_desconhecida = round(desconhecida*100/numero_palavras, 2)
    print(f"{taxa_acerto}% de {numero_palavras} palavras, desconhecida é {taxa_desconhecida}%")

vocabulario = set(lista_normalizada)
avaliador(lista_teste, vocabulario)
# Out:
# 76.34% de 186 palavras, desconhecida é 6.99%

# %%
palavra = "lóiigica"
print(novo_corretor(palavra))
print(corretor(palavra))
# Out:
# lógica
# alóiigica
